# %% [markdown]
# <a href="https://colab.research.google.com/github/MegAgainDev/ai-mlaas-object-detection-YOLOv8/blob/main/ai_mlaas_object_detection_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 13.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
import os

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('/content/bus.jpg')
results[0].save("/content/results_SAVED.jpg")
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 255.8ms
# Speed: 20.8ms preprocess, 255.8ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 480)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-b61630d9632f> in <cell line: 2>()
#       1 results = model('https://ultralytics.com/images/bus.jpg')
# ----> 2 results[0].save("/content/movie_trailor.mp4")
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/results.py in save(self, filename, *args, **kwargs)
#     625         if not filename:
#     626             filename = f"results_{Path(self.path).name}"
# --> 627         self.plot(save=True, filename=filename, *args, **kwargs)
#     628         return filename
#     629
#
# ...

# %%
result = model.predict(source="movie_trailor.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/810) /content/movie_trailor.mp4: 320x640 (no detections), 180.3ms
# video 1/1 (frame 2/810) /content/movie_trailor.mp4: 320x640 (no detections), 150.1ms
# video 1/1 (frame 3/810) /content/movie_trailor.mp4: 320x640 (no detections), 140.2ms
# video 1/1 (frame 4/810) /content/movie_trailor.mp4: 320x640 (no detections), 129.9ms
# video 1/1 (frame 5/810) /content/movie_trailor.mp4: 320x640 (no detections), 127.4ms
# ...
